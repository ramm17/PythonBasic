# %%
# String

# %%
a='Hello world'
b="Hello world"
c='''Hello world'''
print(a,type(a))
print(b,type(b))
print(c,type(c))
# Out:
# Hello world <class 'str'>
# Hello world <class 'str'>
# Hello world <class 'str'>

# %%
# + *
a="Hello world\n"
print(a*2)
# Out:
# Hello world
# Hello world

# %%
a="Hello"
b="world"
c=a+" "+b
print(c)
# Out:
# Hello world

# %%
a="Hello world"
a[0]
# Out:
# 'H'

# %%
a="Hello world"
b= a[0:5]
b
# Out:
# 'Hello'

# %%
a="Hello world"
b=a[0:11:2]
b
# Out:
# 'Hlowrd'

# %%
a="Hello world"
b=a[10::-1]
b
# Out:
# 'dlrow olleH'

# %%
a="Hello world"
b=a[::-1]
b
# Out:
# 'dlrow olleH'

# %%
# String formatting
name="Ramm"
age=24
data=f"Hello my name {name}. I am {age}."
data
# Out:
# 'Hello my name Ramm. I am 24.'

# %%
name=input("Enter your name:")
age=int(input("Enter your age:"))
add=input("Enter your address:")
data=f"Hello i am {name}. I am from {add}. I'm {age} years old."
data
# Out:
# Enter your name:Ramm
# Enter your age:24
# Enter your address:Dhangadhi
# "Hello i am Ramm. I am from Dhangadhi. I'm 24 years old."

# %%
#Bill
s=str()
n=int(input("Enter the value of n="))
for i in range(n):
    name=input("Enter name:")
    price=int(input("Enter the price:"))
    quantity=int(input("Enter the quantity:"))
    total=price*quantity
    bill=f"{name} {price} {quantity} {total}\n"
    s=s+bill
print(s)
# Out:
# Enter the value of n=2
# Enter name:apple
# Enter the price:200
# Enter the quantity:4
# Enter name:banana
# Enter the price:100
# Enter the quantity:2
# apple 200 4 800
# banana 100 2 200

# %%
s
# Out:
# 'apple 200 4 800\nbanana 100 2 200\n'

# %%
s="Ram Shyam Hari Sita Gita Ramesh"
if "Ram" in s:
    print("YEs")
else:
    print("No")
# Out:
# YEs

# %%
s="Ram Shyam Hari Sita Gita Ramesh"
search=input("Enter s=")
if search in s:
    print("YEs")
    print(s.count(search))
else:
    print("No")
# Out:
# Enter s=ram
# No

# %%
s="Ram Shyam Hari Sita Gita Ramesh"
s=s.upper()
print(s)
# Out:
# RAM SHYAM HARI SITA GITA RAMESH

# %%
s="Ram Shyam Hari Sita Gita Ramesh".lower()
search=input("Enter s=").lower()
if search in s:
    print("YEs")
    print(s.count(search))
else:
    print("No")
# Out:
# Enter s=ram
# YEs
# 2

# %%
# Replace function
s="Ram Shyam Hari Sita Gita Ramesh"
s.replace("Hari","hari")
# Out:
# 'Ram Shyam hari Sita Gita Ramesh'

# %%
s="Ram Shyam Hari Sita Gita Ramesh"
s.split()
# Out:
# ['Ram', 'Shyam', 'Hari', 'Sita', 'Gita', 'Ramesh']
