# %%
# file=open('<file_path>','<mode>')
# file.close()

# %%
# with open('<file_name>','<mode>')as file:
#     <operations>

# %%
# mode
# read -> 'r'
# create -> 'x'
# write -> 'w'
# append -> 'a'

# %%
#create file
try:
    file=open('new_file.txt','x')
    file.close()
except:
    print("The file is already created.")

# %%
# Read file

file=open('new_file.txt','r')
x=file.read()
print(x)
print(type(x))
file.close()
# Out:
# Hello world
# Hello world
# Hello world
# Hello world
# Hello world
#
# <class 'str'>

# %%
n=int(input("Enter n="))
x.split('\n')[n-1]
# Out:
# Enter n=5
# 'Hello world'

# %%
with open('data.txt','w')as file:
    file.write('Hello World')

# %%
s=""
n=int(input("Enter n="))
for i in range(n):
    name=input("Enter name ")
    age=int(input("Enter age "))
    add=input("Enter address")
    s=s+f"{name} {age} {add}\n"
    
with open('data.txt','w')as file:
    file.write(s)
# Out:
# Enter n=3
# Enter name Ram
# Enter age 22
# Enter addressDHn
# Enter name Prm
# Enter age 22
# Enter addressKtm
# Enter name Shyam
# Enter age 23
# Enter addressKtm

# %%
pwd
# Out:
# 'C:\\Users\\DELL\\Python Porgrams'

# %%
#Bill
s=str()
n=int(input("Enter the value of n="))
for i in range(n):
    name=input("Enter name:")
    price=int(input("Enter the price:"))
    quantity=int(input("Enter the quantity:"))
    total=price*quantity
    bill=f"{name} {price} {quantity} {total}\n"
    s=s+bill
print(s)
with open('bill.txt','w')as file:
    file.write(s)
# Out:
# Enter the value of n=2
# Enter name:Apple
# Enter the price:250
# Enter the quantity:2
# Enter name:Mango
# Enter the price:150
# Enter the quantity:3
# Apple 250 2 500
# Mango 150 3 450

# %%
#csv file excel file
s=str()
n=int(input("Enter the value of n="))
for i in range(n):
    name=input("Enter name:")
    price=int(input("Enter the price:"))
    quantity=int(input("Enter the quantity:"))
    total=price*quantity
    bill=f"{name},{price},{quantity},{total}\n"
    s=s+bill
print(s)
with open('bill.csv','w') as file:
    file.write('Name,Price,Quantity,Total\n')
    file.write(s)
# Out:
# Enter the value of n=2
# Enter name:Apple
# Enter the price:250
# Enter the quantity:2
# Enter name:Orange
# Enter the price:150
# Enter the quantity:3
# Apple,250,2,500
# Orange,150,3,450

# %%
import pandas as pd
df=pd.read_csv('bill.csv')
df
# Out:
#      Name  Price  Quantity  Total
# 0   Apple    250         2    500
# 1  Orange    150         3    450

# %%
import pandas as pd
df=pd.read_csv('bill.csv')
df
# Out:
#      Name  Price  Quantity  Total
# 0   Apple    250         2    500
# 1  Orange    150         3    450

# %%
import csv
a=[['Name','Price','Quantity','Total'],
   ['Momo',200,3,600],
   ['Coke',100,2,200]]
with open('tbill.csv','w')as file:
    x=csv.writer(file)
    x.writerows(a)

# %%
import csv
with open('tbill.csv','r')as file:
    reader=csv.DictReader(file)
    for i in reader:
        print(i)
# Out:
# {'Name': 'Momo', 'Price': '200', 'Quantity': '3', 'Total': '600'}
# {'Name': 'Coke', 'Price': '100', 'Quantity': '2', 'Total': '200'}

# %%
#Dictionary inside list
import csv
data=[]
with open('tbill.csv','r')as file:
    reader=csv.DictReader(file)
    for i in reader:
        data.append(i)
        
data
# Out:
# [{'Name': 'Momo', 'Price': '200', 'Quantity': '3', 'Total': '600'},
#  {'Name': 'Coke', 'Price': '100', 'Quantity': '2', 'Total': '200'}]

# %%
file=open('bill.csv','r')
x=file.read()
y=x.split('\n')
print(y)
file.close()
# Out:
# ['Name,Price,Quantity,Total', 'Apple,250,2,500', 'Orange,150,3,450', '']

# %%
all_result=[]
for i in y[0:-1]:
    all_result.append(i.split(','))
    
all_result
# Out:
# [['Name', 'Price', 'Quantity', 'Total'],
#  ['Apple', '250', '2', '500'],
#  ['Orange', '150', '3', '450']]

# %%
import csv
a=['Pizza',200,4,800]
with open('tbill.csv','a')as file:
    x=csv.writer(file)
    x.writerow(a)

# %%
import pandas as pd
df=pd.read_csv("tbill.csv")
df
# Out:
#     Name  Price  Quantity  Total
# 0   Momo    200         3    600
# 1   Coke    100         2    200
# 2  Pizza    200         4    800
